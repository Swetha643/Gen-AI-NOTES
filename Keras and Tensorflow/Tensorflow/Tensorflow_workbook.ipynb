# %%
import tensorflow as tf
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# Constants

con1=tf.constant(10)
con2=tf.constant(3.14)
con3=tf.constant("This is tensorflow")
con4=tf.constant(True)

# %%
print(con1,con2,con3,con4)
# Out:
# tf.Tensor(10, shape=(), dtype=int32) tf.Tensor(3.14, shape=(), dtype=float32) tf.Tensor(b'This is tensorflow', shape=(), dtype=string) tf.Tensor(True, shape=(), dtype=bool)

# %%
import tensorflow as tf

# Your TensorFlow operations here (no session needed)
x = tf.constant([1, 2, 3])
y = x * 2
print(y)  # Output: tf.Tensor([2 4 6], shape=(3,), dtype=int32)
# Out:
# tf.Tensor([2 4 6], shape=(3,), dtype=int32)

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.15.0

# %%
#operations

Addition= tf.constant(20) + tf.constant(30)
Mul= tf.constant(20) * tf.constant(30)

# %%
# Create a matrix (tensor)
matrix = tf.constant([1, 2, 3])+ tf.constant([4, 5, 6])

# Print the matrix
print(matrix)
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)

# %%
str1=tf.constant("I love ")
str2=tf.constant("tensorflow")

print(str1+str2)
# Out:
# tf.Tensor(b'I love tensorflow', shape=(), dtype=string)

# %% [markdown]
# # Placeholder

# %%
a=tf.placeholder(tf.int32)
b=a*2
sess.run(b,feed_dict={a:[1,2,3,4,5]})

# output: array([2,4,6,8,10])

# %%
str_name=tf.placeholder(tf.string)
my_name="I am "+str_name
sess.run(my name,feed_dic={str_name:["sam","bob","charleie"]})

# output: array([b' I am sam',b'I am bob, I am charlie]),dtype=object

# %% [markdown]
# # Variable

# %%
var1 =tf.Variable([20],tf.int32)

# %%
init=tf.global_variables_initializer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-82729305d964> in <cell line: 1>()
# ----> 1 init=tf.global_variables_initializer()
#
# AttributeError: module 'tensorflow' has no attribute 'global_variables_initializer'

# %% [markdown]
# # Intro to neural Network
